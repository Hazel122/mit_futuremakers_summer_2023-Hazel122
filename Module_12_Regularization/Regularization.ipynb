# %% [markdown]
# <a href="https://colab.research.google.com/github/MySureStart/mit_futuremakers_summer_2023-Hazel122/blob/main/Module_12_Regularization/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Objective
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %%
# Basic packages
import pandas as pd
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence

root = Path('../content/')
input_path = root / 'input/'
ouput_path = root / 'output/'
source_path = root / 'source/'

def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])

    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history

def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split()
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1]
    return " ".join(clean_words)

def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=1)
    results = model.evaluate(X_test, y_test)
    print()
    print('Test accuracy: {0:.2f}%'.format(results[1]*100))
    return results

def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)

    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }

    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()

def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch

! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
! mkdir input/
! mv Tweets.csv input/

df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)

X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)

tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')

le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_history = deep_model(base_model, X_train_rest, y_train_rest, X_valid, y_valid)
base_min = optimal_epoch(base_history)

reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 95.7MB/s]
# mkdir: cannot create directory ‘input/’: File exists
# Epoch 1/20
# 24/24 [==============================] - 4s 118ms/step - loss: 0.8927 - accuracy: 0.6149 - val_loss: 0.7700 - val_accuracy: 0.6267
# Epoch 2/20
# 24/24 [==============================] - 3s 118ms/step - loss: 0.6540 - accuracy: 0.7178 - val_loss: 0.6201 - val_accuracy: 0.7542
# Epoch 3/20
# 24/24 [==============================] - 4s 147ms/step - loss: 0.5080 - accuracy: 0.8205 - val_loss: 0.5567 - val_accuracy: 0.7785
# Epoch 4/20
# 24/24 [==============================] - 3s 119ms/step - loss: 0.4130 - accuracy: 0.8574 - val_loss: 0.5299 - val_accuracy: 0.7830
# Epoch 5/20
# 24/24 [==============================] - 2s 63ms/step - loss: 0.3470 - accuracy: 0.8795 - val_loss: 0.5226 - val_accuracy: 0.7876
# Epoch 6/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.2959 - accuracy: 0.8980 - val_loss: 0.5500 - val_accuracy: 0.7792
# Epoch 7/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.2564 - accuracy: 0.9134 - val_loss: 0.5799 - val_accuracy: 0.7747
# Epoch 8/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.2224 - accuracy: 0.9260 - val_loss: 0.6012 - val_accuracy: 0.7883
# Epoch 9/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.1927 - accuracy: 0.9351 - val_loss: 0.6380 - val_accuracy: 0.7777
# Epoch 10/20
# 24/24 [==============================] - 2s 78ms/step - loss: 0.1673 - accuracy: 0.9447 - val_loss: 0.6678 - val_accuracy: 0.7754
# Epoch 11/20
# 24/24 [==============================] - 2s 88ms/step - loss: 0.1452 - accuracy: 0.9524 - val_loss: 0.7148 - val_accuracy: 0.7656
# Epoch 12/20
# 24/24 [==============================] - 2s 67ms/step - loss: 0.1279 - accuracy: 0.9586 - val_loss: 0.7445 - val_accuracy: 0.7762
# Epoch 13/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.1122 - accuracy: 0.9647 - val_loss: 0.8039 - val_accuracy: 0.7633
# Epoch 14/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0987 - accuracy: 0.9695 - val_loss: 0.8420 - val_accuracy: 0.7595
# Epoch 15/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0871 - accuracy: 0.9728 - val_loss: 0.8679 - val_accuracy: 0.7709
# Epoch 16/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0773 - accuracy: 0.9766 - val_loss: 0.9073 - val_accuracy: 0.7739
# Epoch 17/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0684 - accuracy: 0.9785 - val_loss: 0.9892 - val_accuracy: 0.7542
# Epoch 18/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0615 - accuracy: 0.9820 - val_loss: 0.9983 - val_accuracy: 0.7701
# Epoch 19/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0554 - accuracy: 0.9834 - val_loss: 1.0511 - val_accuracy: 0.7504
# Epoch 20/20
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0504 - accuracy: 0.9847 - val_loss: 1.0668 - val_accuracy: 0.7663
# Minimum validation loss reached in epoch 5
# Epoch 1/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.9339 - accuracy: 0.6222 - val_loss: 0.8421 - val_accuracy: 0.6259
# Epoch 2/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.7635 - accuracy: 0.6666 - val_loss: 0.7514 - val_accuracy: 0.6722
# Epoch 3/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.6738 - accuracy: 0.7115 - val_loss: 0.6911 - val_accuracy: 0.7041
# Epoch 4/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.6077 - accuracy: 0.7583 - val_loss: 0.6447 - val_accuracy: 0.7428
# Epoch 5/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.5547 - accuracy: 0.7961 - val_loss: 0.6092 - val_accuracy: 0.7678
# Epoch 6/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.5114 - accuracy: 0.8231 - val_loss: 0.5819 - val_accuracy: 0.7747
# Epoch 7/20
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4751 - accuracy: 0.8420 - val_loss: 0.5604 - val_accuracy: 0.7807
# Epoch 8/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.4441 - accuracy: 0.8534 - val_loss: 0.5439 - val_accuracy: 0.7860
# Epoch 9/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.4176 - accuracy: 0.8635 - val_loss: 0.5356 - val_accuracy: 0.7876
# Epoch 10/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.3953 - accuracy: 0.8693 - val_loss: 0.5240 - val_accuracy: 0.7944
# Epoch 11/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.3750 - accuracy: 0.8773 - val_loss: 0.5165 - val_accuracy: 0.7967
# Epoch 12/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.3569 - accuracy: 0.8835 - val_loss: 0.5138 - val_accuracy: 0.7929
# Epoch 13/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.3406 - accuracy: 0.8883 - val_loss: 0.5099 - val_accuracy: 0.7944
# Epoch 14/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.3262 - accuracy: 0.8943 - val_loss: 0.5091 - val_accuracy: 0.7936
# Epoch 15/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.3131 - accuracy: 0.8979 - val_loss: 0.5112 - val_accuracy: 0.7959
# Epoch 16/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.3007 - accuracy: 0.9017 - val_loss: 0.5125 - val_accuracy: 0.7959
# Epoch 17/20
# 24/24 [==============================] - 1s 33ms/step - loss: 0.2894 - accuracy: 0.9060 - val_loss: 0.5149 - val_accuracy: 0.7997
# Epoch 18/20
# 24/24 [==============================] - 1s 33ms/step - loss: 0.2791 - accuracy: 0.9093 - val_loss: 0.5180 - val_accuracy: 0.7997
# Epoch 19/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.2692 - accuracy: 0.9125 - val_loss: 0.5217 - val_accuracy: 0.8005
# Epoch 20/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.2599 - accuracy: 0.9150 - val_loss: 0.5250 - val_accuracy: 0.8027
# Minimum validation loss reached in epoch 14

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                640064
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dense_10 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 3s 80ms/step - loss: 1.0593 - accuracy: 0.6160 - val_loss: 0.9122 - val_accuracy: 0.6586
# Epoch 2/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.7941 - accuracy: 0.7265 - val_loss: 0.7554 - val_accuracy: 0.7610
# Epoch 3/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.6465 - accuracy: 0.8173 - val_loss: 0.6809 - val_accuracy: 0.7815
# Epoch 4/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.5537 - accuracy: 0.8493 - val_loss: 0.6409 - val_accuracy: 0.7944
# Epoch 5/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.4919 - accuracy: 0.8724 - val_loss: 0.6366 - val_accuracy: 0.7959
# Epoch 6/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.4471 - accuracy: 0.8844 - val_loss: 0.6358 - val_accuracy: 0.7967
# Epoch 7/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.4116 - accuracy: 0.8992 - val_loss: 0.6523 - val_accuracy: 0.7929
# Epoch 8/20
# 24/24 [==============================] - 2s 74ms/step - loss: 0.3821 - accuracy: 0.9100 - val_loss: 0.6705 - val_accuracy: 0.7921
# Epoch 9/20
# 24/24 [==============================] - 2s 92ms/step - loss: 0.3585 - accuracy: 0.9185 - val_loss: 0.6760 - val_accuracy: 0.7860
# Epoch 10/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.3372 - accuracy: 0.9261 - val_loss: 0.7019 - val_accuracy: 0.7777
# Epoch 11/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.3218 - accuracy: 0.9315 - val_loss: 0.7030 - val_accuracy: 0.7898
# Epoch 12/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.3046 - accuracy: 0.9382 - val_loss: 0.7194 - val_accuracy: 0.7830
# Epoch 13/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.2913 - accuracy: 0.9433 - val_loss: 0.7365 - val_accuracy: 0.7822
# Epoch 14/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.2792 - accuracy: 0.9445 - val_loss: 0.7649 - val_accuracy: 0.7731
# Epoch 15/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2678 - accuracy: 0.9521 - val_loss: 0.7657 - val_accuracy: 0.7807
# Epoch 16/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2567 - accuracy: 0.9560 - val_loss: 0.7790 - val_accuracy: 0.7747
# Epoch 17/20
# 24/24 [==============================] - 2s 68ms/step - loss: 0.2476 - accuracy: 0.9601 - val_loss: 0.7900 - val_accuracy: 0.7769
# Epoch 18/20
# 24/24 [==============================] - 2s 95ms/step - loss: 0.2396 - accuracy: 0.9625 - val_loss: 0.8014 - val_accuracy: 0.7640
# Epoch 19/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.2323 - accuracy: 0.9648 - val_loss: 0.8013 - val_accuracy: 0.7724
# Epoch 20/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.2245 - accuracy: 0.9674 - val_loss: 0.8216 - val_accuracy: 0.7663
# Minimum validation loss reached in epoch 6

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 1
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 1

# %%
weights = [-5, 4, -3, 2, 1]
lambda_ = 0.01

def l1_norm(weights, lambda_):
    # Enter your code here
    reg = sum(abs(w) for w in weights) * lambda_
    return reg

print(l1_norm(weights, lambda_))
# Out:
# 0.15

# %% [markdown]
# ## Question 2
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 2

# %%
weights = [-5, 4, -3, 2, 1]
lambda_ = 0.01

def l2_norm(weights, lambda_):
    # Enter your code here
    reg = sum(w**2 for w in weights) * lambda_
    return reg

print(l2_norm(weights, lambda_))
# Out:
# 0.55

# %% [markdown]
# ## Adding dropout layers
# Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 64)                640064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_12 (Dense)            (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 69ms/step - loss: 0.9034 - accuracy: 0.6071 - val_loss: 0.7868 - val_accuracy: 0.6070
# Epoch 2/20
# 24/24 [==============================] - 2s 89ms/step - loss: 0.7275 - accuracy: 0.6583 - val_loss: 0.6950 - val_accuracy: 0.7011
# Epoch 3/20
# 24/24 [==============================] - 2s 80ms/step - loss: 0.6326 - accuracy: 0.7489 - val_loss: 0.6194 - val_accuracy: 0.7656
# Epoch 4/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.5514 - accuracy: 0.7990 - val_loss: 0.5705 - val_accuracy: 0.7792
# Epoch 5/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.4836 - accuracy: 0.8284 - val_loss: 0.5461 - val_accuracy: 0.7876
# Epoch 6/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.4394 - accuracy: 0.8477 - val_loss: 0.5356 - val_accuracy: 0.7914
# Epoch 7/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.4034 - accuracy: 0.8597 - val_loss: 0.5459 - val_accuracy: 0.7876
# Epoch 8/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.3670 - accuracy: 0.8738 - val_loss: 0.5478 - val_accuracy: 0.7876
# Epoch 9/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.3346 - accuracy: 0.8865 - val_loss: 0.5521 - val_accuracy: 0.7929
# Epoch 10/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.3108 - accuracy: 0.8972 - val_loss: 0.5620 - val_accuracy: 0.7914
# Epoch 11/20
# 24/24 [==============================] - 2s 86ms/step - loss: 0.2844 - accuracy: 0.9044 - val_loss: 0.5861 - val_accuracy: 0.7944
# Epoch 12/20
# 24/24 [==============================] - 2s 76ms/step - loss: 0.2647 - accuracy: 0.9143 - val_loss: 0.5867 - val_accuracy: 0.7974
# Epoch 13/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.2515 - accuracy: 0.9143 - val_loss: 0.5989 - val_accuracy: 0.7936
# Epoch 14/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2288 - accuracy: 0.9244 - val_loss: 0.6287 - val_accuracy: 0.7967
# Epoch 15/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2085 - accuracy: 0.9287 - val_loss: 0.6511 - val_accuracy: 0.7936
# Epoch 16/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.1938 - accuracy: 0.9357 - val_loss: 0.6753 - val_accuracy: 0.7914
# Epoch 17/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.1832 - accuracy: 0.9407 - val_loss: 0.6876 - val_accuracy: 0.7914
# Epoch 18/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.1660 - accuracy: 0.9448 - val_loss: 0.7126 - val_accuracy: 0.7883
# Epoch 19/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.1597 - accuracy: 0.9488 - val_loss: 0.7320 - val_accuracy: 0.7898
# Epoch 20/20
# 24/24 [==============================] - 2s 79ms/step - loss: 0.1474 - accuracy: 0.9500 - val_loss: 0.7535 - val_accuracy: 0.7883
# Minimum validation loss reached in epoch 6

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3)
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 9s 345ms/step - loss: 1.5519 - accuracy: 0.1773 - val_loss: 1.0483 - val_accuracy: 0.1920
# Epoch 2/20
# 24/24 [==============================] - 8s 322ms/step - loss: 2.6160 - accuracy: 0.1114 - val_loss: 8.2550 - val_accuracy: 0.0766
# Epoch 3/20
# 24/24 [==============================] - 8s 354ms/step - loss: 4.2201 - accuracy: 0.3880 - val_loss: 6.7604 - val_accuracy: 0.6070
# Epoch 4/20
# 24/24 [==============================] - 7s 299ms/step - loss: 7.3950 - accuracy: 0.6273 - val_loss: 9.9639 - val_accuracy: 0.6070
# Epoch 5/20
# 24/24 [==============================] - 9s 361ms/step - loss: 7.5516 - accuracy: 0.6270 - val_loss: 2.4991 - val_accuracy: 0.6131
# Epoch 6/20
# 24/24 [==============================] - 8s 346ms/step - loss: 8.0329 - accuracy: 0.6267 - val_loss: 10.0397 - val_accuracy: 0.6070
# Epoch 7/20
# 24/24 [==============================] - 7s 300ms/step - loss: 9.7341 - accuracy: 0.6278 - val_loss: 10.1030 - val_accuracy: 0.6070
# Epoch 8/20
# 24/24 [==============================] - 8s 354ms/step - loss: 6.9972 - accuracy: 0.5767 - val_loss: 11.5336 - val_accuracy: 0.6017
# Epoch 9/20
# 24/24 [==============================] - 7s 298ms/step - loss: 8.1929 - accuracy: 0.6198 - val_loss: 11.4845 - val_accuracy: 0.6070
# Epoch 10/20
# 24/24 [==============================] - 9s 368ms/step - loss: 8.6838 - accuracy: 0.6280 - val_loss: 12.7890 - val_accuracy: 0.6070
# Epoch 11/20
# 24/24 [==============================] - 8s 356ms/step - loss: 7.8603 - accuracy: 0.6277 - val_loss: 4.6603 - val_accuracy: 0.6070
# Epoch 12/20
# 24/24 [==============================] - 7s 301ms/step - loss: 6.9945 - accuracy: 0.6273 - val_loss: 14.0022 - val_accuracy: 0.6070
# Epoch 13/20
# 24/24 [==============================] - 8s 355ms/step - loss: 6.8671 - accuracy: 0.6262 - val_loss: 3.0875 - val_accuracy: 0.6070
# Epoch 14/20
# 24/24 [==============================] - 7s 304ms/step - loss: 7.5350 - accuracy: 0.6276 - val_loss: 13.4353 - val_accuracy: 0.6070
# Epoch 15/20
# 24/24 [==============================] - 8s 341ms/step - loss: 8.5598 - accuracy: 0.6278 - val_loss: 10.6720 - val_accuracy: 0.6070
# Epoch 16/20
# 24/24 [==============================] - 8s 356ms/step - loss: 7.8214 - accuracy: 0.6268 - val_loss: 10.3472 - val_accuracy: 0.6070
# Epoch 17/20
# 24/24 [==============================] - 7s 304ms/step - loss: 7.9112 - accuracy: 0.6270 - val_loss: 10.8171 - val_accuracy: 0.6070
# Epoch 18/20
# 24/24 [==============================] - 8s 356ms/step - loss: 8.0635 - accuracy: 0.6262 - val_loss: 9.9662 - val_accuracy: 0.6070
# Epoch 19/20
# 24/24 [==============================] - 8s 328ms/step - loss: 7.9504 - accuracy: 0.6262 - val_loss: 5.7088 - val_accuracy: 0.6070
# Epoch 20/20
# 24/24 [==============================] - 8s 318ms/step - loss: 5.1568 - accuracy: 0.6159 - val_loss: 3.5151 - val_accuracy: 0.6070
# Minimum validation loss reached in epoch 1

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 3
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?

# %% [markdown]
# ### Answer 3
#
# When it is an overly-complex, overfitted model. L2 regularization can encourage model to spread the weights evenly to different neurons, and dropout layers can drop out random neurons to prevent the network relying on specific neurons.

# %% [markdown]
# #Training on the full train data and evaluation on test data
# At first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 1s 57ms/step - loss: 0.1482 - accuracy: 0.9630
# Epoch 2/5
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1003 - accuracy: 0.9714
# Epoch 3/5
# 26/26 [==============================] - 1s 51ms/step - loss: 0.0785 - accuracy: 0.9761
# Epoch 4/5
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0636 - accuracy: 0.9816
# Epoch 5/5
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0528 - accuracy: 0.9846
# 46/46 [==============================] - 0s 4ms/step - loss: 1.0898 - accuracy: 0.7616
#
# Test accuracy: 76.16%

# %%
reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Epoch 1/14
# 26/26 [==============================] - 1s 31ms/step - loss: 0.2787 - accuracy: 0.9059
# Epoch 2/14
# 26/26 [==============================] - 1s 31ms/step - loss: 0.2676 - accuracy: 0.9097
# Epoch 3/14
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2576 - accuracy: 0.9139
# Epoch 4/14
# 26/26 [==============================] - 1s 29ms/step - loss: 0.2484 - accuracy: 0.9163
# Epoch 5/14
# 26/26 [==============================] - 1s 29ms/step - loss: 0.2397 - accuracy: 0.9188
# Epoch 6/14
# 26/26 [==============================] - 1s 29ms/step - loss: 0.2315 - accuracy: 0.9218
# Epoch 7/14
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2239 - accuracy: 0.9249
# Epoch 8/14
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2166 - accuracy: 0.9274
# Epoch 9/14
# 26/26 [==============================] - 1s 27ms/step - loss: 0.2096 - accuracy: 0.9306
# Epoch 10/14
# 26/26 [==============================] - 1s 29ms/step - loss: 0.2031 - accuracy: 0.9325
# Epoch 11/14
# 26/26 [==============================] - 1s 33ms/step - loss: 0.1971 - accuracy: 0.9353
# Epoch 12/14
# 26/26 [==============================] - 1s 44ms/step - loss: 0.1911 - accuracy: 0.9380
# Epoch 13/14
# 26/26 [==============================] - 1s 42ms/step - loss: 0.1856 - accuracy: 0.9386
# Epoch 14/14
# 26/26 [==============================] - 1s 36ms/step - loss: 0.1801 - accuracy: 0.9423
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5952 - accuracy: 0.7869
#
# Test accuracy: 78.69%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/6
# 26/26 [==============================] - 2s 93ms/step - loss: 0.2828 - accuracy: 0.9485
# Epoch 2/6
# 26/26 [==============================] - 3s 107ms/step - loss: 0.2505 - accuracy: 0.9566
# Epoch 3/6
# 26/26 [==============================] - 3s 113ms/step - loss: 0.2337 - accuracy: 0.9622
# Epoch 4/6
# 26/26 [==============================] - 3s 132ms/step - loss: 0.2235 - accuracy: 0.9646
# Epoch 5/6
# 26/26 [==============================] - 1s 51ms/step - loss: 0.2179 - accuracy: 0.9675
# Epoch 6/6
# 26/26 [==============================] - 1s 50ms/step - loss: 0.2099 - accuracy: 0.9713
# 46/46 [==============================] - 0s 6ms/step - loss: 0.8023 - accuracy: 0.7753
#
# Test accuracy: 77.53%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/6
# 26/26 [==============================] - 1s 52ms/step - loss: 0.2066 - accuracy: 0.9360
# Epoch 2/6
# 26/26 [==============================] - 2s 87ms/step - loss: 0.1871 - accuracy: 0.9425
# Epoch 3/6
# 26/26 [==============================] - 2s 66ms/step - loss: 0.1734 - accuracy: 0.9454
# Epoch 4/6
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1559 - accuracy: 0.9487
# Epoch 5/6
# 26/26 [==============================] - 1s 51ms/step - loss: 0.1448 - accuracy: 0.9537
# Epoch 6/6
# 26/26 [==============================] - 1s 48ms/step - loss: 0.1338 - accuracy: 0.9564
# 46/46 [==============================] - 0s 4ms/step - loss: 0.7943 - accuracy: 0.7862
#
# Test accuracy: 78.62%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# here are the ways to prevent underfitting
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# visualize the regularized **cost function**

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 1
#
# Plot the same for L1 regularization

# %% [markdown]
# ### Answer

# %%
cost = lambda w: .5*np.mean(abs(w[0] + w[1]*x - y))
l1_penalty = lambda w: np.dot(w,w)/2
cost_plus_l1 = lambda w: cost(w) + 5*l1_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||_2^2$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualization to what the L1 and L2 normalizations, how do they help while training?
#
# L1 vs L2: L1 results in sparsity, L2 get close to zero
#
# They restrain the weights to be in a certain domain, and then reduces the complexity of the model to prevent overfitting.

# %% [markdown]
# # Upload this Colab Notebook to your Github repository. Also add your *reflections* on today's learning in README.md
